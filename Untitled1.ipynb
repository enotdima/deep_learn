# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

from pathlib import Path
# Determine the locations of auxiliary libraries and datasets.
# `AUX_DATA_ROOT` is where 'notmnist.py', 'animation.py' and 'tiny-imagenet-2020.zip' are.
if IN_COLAB:
    google.colab.drive.mount("/content/drive")
    
    # Change this if you created the shortcut in a different location
    AUX_DATA_ROOT = Path("/content/drive/My Drive/Deep Learning 2020 -- Home Assignment 2")
    
    assert AUX_DATA_ROOT.is_dir(), "Have you forgot to 'Add a shortcut to Drive'?"
else:
    AUX_DATA_ROOT = Path(".")

# %%
from pathlib import Path
if not Path("tiny-imagenet-200/train/class_000/00000.jpg").is_file():
    import zipfile
    with zipfile.ZipFile(AUX_DATA_ROOT / 'tiny-imagenet-2020.zip', 'r') as archive:
        archive.extractall()

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision.datasets as datasets
import torch.utils.data as data
import torchvision.transforms as transforms
from torch.autograd import Variable
import torchvision.models as models
import matplotlib.pyplot as plt
import time, os, copy, numpy as np
from livelossplot import PlotLosses

# %matplotlib inline

# %%
import torch, time, copy, sys, os
import matplotlib.pyplot as plt
from livelossplot import PlotLosses

def train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs=5, scheduler=None):
    if not os.path.exists('models/'+str(output_path)):
        os.makedirs('models/'+str(output_path))
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    since = time.time()
    liveloss = PlotLosses()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best = 0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i,(inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                print("\rIteration: {}/{}, Loss: {}.".format(i+1, len(dataloaders[phase]), loss.item() * inputs.size(0)), end="")

#                 print( (i+1)*100. / len(dataloaders[phase]), "% Complete" )
                sys.stdout.flush()
                
            if scheduler != None:
                scheduler.step()  
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            if phase == 'train':
                avg_loss = epoch_loss
                t_acc = epoch_acc
            else:
                val_loss = epoch_loss
                val_acc = epoch_acc
            
#             print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                 phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best = epoch + 1
                best_model_wts = copy.deepcopy(model.state_dict())
                
        liveloss.update({
            'log loss': avg_loss,
            'val_log loss': val_loss,
            'accuracy': t_acc,
            'val_accuracy': val_acc
        })
                
        liveloss.draw()
        print('Train Loss: {:.4f} Acc: {:.4f}'.format(avg_loss, t_acc))
        print(  'Val Loss: {:.4f} Acc: {:.4f}'.format(val_loss, val_acc))
        print()
        if epoch % 5 == 0:
            torch.save(model.state_dict(), './models/' + str(output_path) + '/model_{}_epoch.pt'.format(epoch+1))
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best Validation Accuracy: {}, Epoch: {}'.format(best_acc, best))

# %%
for k in range(10):
    if k % 5 == 0:
        print(k)
# Out:
# 0
# 5

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.1)


#Train
model_ft = train_model('model_1',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 35, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.007, max:    0.518, cur:    0.515)
# 	validation       	 (min:    0.007, max:    0.412, cur:    0.411)
# log loss
# 	training         	 (min:    1.944, max:    5.509, cur:    1.948)
# 	validation       	 (min:    2.464, max:    5.507, cur:    2.467)
# Train Loss: 1.9484 Acc: 0.5151
# Val Loss: 2.4671 Acc: 0.4107
#
# Training complete in 30m 28s
# Best Validation Accuracy: 0.4118, Epoch: 14

# %%
from albumentations import (Rotate, Compose, RandomBrightnessContrast,
                            Normalize, HorizontalFlip, VerticalFlip,
                            RandomResizedCrop, ShiftScaleRotate)
from albumentations.pytorch import ToTensorV2 as ToTensor

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005, nesterov = True)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)

#Train
model_ft = train_model('model_rot_mult_norm',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.060, max:    0.619, cur:    0.619)
# 	validation       	 (min:    0.088, max:    0.457, cur:    0.457)
# log loss
# 	training         	 (min:    1.477, max:    4.683, cur:    1.477)
# 	validation       	 (min:    2.319, max:    4.369, cur:    2.345)
# Train Loss: 1.4767 Acc: 0.6189
# Val Loss: 2.3453 Acc: 0.4568
#
# Training complete in 45m 42s
# Best Validation Accuracy: 0.4572, Epoch: 45

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.005, nesterov = True)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)

#Train
model_ft = train_model('model_rot_mult_norm_reg',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.007, max:    0.647, cur:    0.527)
# 	validation       	 (min:    0.007, max:    0.459, cur:    0.388)
# log loss
# 	training         	 (min:    1.375, max:    5.509, cur:    1.879)
# 	validation       	 (min:    2.323, max:    5.507, cur:    2.770)
# Train Loss: 1.8785 Acc: 0.5270
# Val Loss: 2.7705 Acc: 0.3882
#
# Epoch 22/50
# ----------
# Iteration: 109/1000, Loss: 160.80803871154785.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-60c587543500> in <module>
#      46
#      47 #Train
# ---> 48 model_ft = train_model('model_rot_mult1',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
#
# <ipython-input-12-ef6d400a36df> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet34()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)

#Train
model_ft = train_model('model_rot_mult_34',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.623, cur:    0.623)
# 	validation       	 (min:    0.062, max:    0.469, cur:    0.447)
# log loss
# 	training         	 (min:    1.462, max:    4.832, cur:    1.462)
# 	validation       	 (min:    2.246, max:    4.623, cur:    2.388)
# Train Loss: 1.4623 Acc: 0.6226
# Val Loss: 2.3883 Acc: 0.4467
#
# Epoch 50/50
# ----------
# Iteration: 17/1000, Loss: 132.40017890930176.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-869cdeb340d7> in <module>
#      46
#      47 #Train
# ---> 48 model_ft = train_model('model_rot_mult_34',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
#
# <ipython-input-3-ef6d400a36df> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      47
#      48                 # statistics
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet34()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.07, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 35], gamma=0.1)

#Train
model_ft = train_model('model_rot_mult_34_1',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.07, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 35], gamma=0.1)

#Train
model_ft = train_model('model_dense_2_b',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.632)
# 	validation       	 (min:    0.062, max:    0.494, cur:    0.473)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    1.451)
# 	validation       	 (min:    2.112, max:    4.623, cur:    2.189)
# Train Loss: 1.4514 Acc: 0.6318
# Val Loss: 2.1888 Acc: 0.4729
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-be95b4ea857f> in <module>
#      46
#      47 #Train
# ---> 48 model_ft = train_model('model_dense_1',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
#
# <ipython-input-3-ef6d400a36df> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      86         print(  'Val Loss: {:.4f} Acc: {:.4f}'.format(val_loss, val_acc))
#      87         print()
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.7, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(35),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.07, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 35], gamma=0.1)

#Train
model_ft = train_model('model_dense_2_b',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.658, cur:    0.658)
# 	validation       	 (min:    0.048, max:    0.515, cur:    0.497)
# log loss
# 	training         	 (min:    1.345, max:    4.849, cur:    1.345)
# 	validation       	 (min:    2.016, max:    5.038, cur:    2.105)
# Train Loss: 1.3451 Acc: 0.6577
# Val Loss: 2.1053 Acc: 0.4973
#
# Epoch 39/50
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-de2334aa4bbb> in <module>
#      46
#      47 #Train
# ---> 48 model_ft = train_model('model_dense_2_b',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
#
# <ipython-input-38-3c9f5138ec9d> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      28
#      29             # Iterate over data.
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.75, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(35),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=200,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.07, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 35], gamma=0.3)

#Train
model_ft = train_model('model_dense_2_m',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.091, max:    0.654, cur:    0.654)
# 	validation       	 (min:    0.097, max:    0.510, cur:    0.479)
# log loss
# 	training         	 (min:    1.331, max:    4.426, cur:    1.331)
# 	validation       	 (min:    2.034, max:    4.416, cur:    2.228)
# Train Loss: 1.3306 Acc: 0.6543
# Val Loss: 2.2285 Acc: 0.4789
#
# Epoch 32/50
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ddeea500ad45> in <module>
#      47
#      48 #Train
# ---> 49 model_ft = train_model('model_dense_2_m',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
#
# <ipython-input-3-3c9f5138ec9d> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      28
#      29             # Iterate over data.
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.75, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(35),
        #transforms.RandomErasing(scale=(0.02, 0.25)),
        transforms.ToTensor(),
        transforms.RandomErasing(scale=(0.02, 0.25)),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.06, momentum=0.9, nesterov = True, weight_decay = 0.003)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 30, 35, 40], gamma=0.5)

#Train
model_ft = train_model('model_dense_2_b_eras',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 50, exp_lr_scheduler)
# Out:
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7fa7347dbc50>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 923, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 903, in _shutdown_workers
#     w.join()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 124, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.6/multiprocessing/popen_fork.py", line 50, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/usr/lib/python3.6/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:
# Epoch 1/50
# ----------
# ---------------------------------------------------------------------------
# ...

# %%
import torch, time, copy, sys, os
import matplotlib.pyplot as plt
from livelossplot import PlotLosses

def train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs=5, scheduler=None):
    if not os.path.exists('models/'+str(output_path)):
        os.makedirs('models/'+str(output_path))
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    since = time.time()
    liveloss = PlotLosses()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best = 0
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i,(inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                print("\rIteration: {}/{}, Loss: {}.".format(i+1, len(dataloaders[phase]), loss.item() * inputs.size(0)), end="")

#                 print( (i+1)*100. / len(dataloaders[phase]), "% Complete" )
                sys.stdout.flush()
                
            if scheduler != None:
                scheduler.step()  
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            if phase == 'train':
                avg_loss = epoch_loss
                t_acc = epoch_acc
            else:
                val_loss = epoch_loss
                val_acc = epoch_acc
            
#             print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                 phase, epoch_loss, epoch_acc))
            flag = False
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                flag = True
                best = epoch + 1
                best_model_wts = copy.deepcopy(model.state_dict())
                
        liveloss.update({
            'log loss': avg_loss,
            'val_log loss': val_loss,
            'accuracy': t_acc,
            'val_accuracy': val_acc
        })
                
        liveloss.draw()
        print('Train Loss: {:.4f} Acc: {:.4f}'.format(avg_loss, t_acc))
        print(  'Val Loss: {:.4f} Acc: {:.4f}'.format(val_loss, val_acc))
        print()
        if flag: #val_acc > val_acc_max:#epoch % 5 == 0:
            torch.save(model.state_dict(), './models/' + str(output_path) + '/model_{}_epoch.pt'.format(epoch+1))
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best Validation Accuracy: {}, Epoch: {}'.format(best_acc, best))

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005, nesterov = True)
optimizer_ft = torch.optim.Adam(model_ft.parameters(), lr=0.001, weight_decay=0.001)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=15, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)
#exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.0001, max_lr=0.001, step_size_up=3000)

#Train
model_ft = train_model('model_res_adam',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.348)
# 	validation       	 (min:    0.062, max:    0.494, cur:    0.317)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.781)
# 	validation       	 (min:    2.112, max:    4.642, cur:    2.941)
# Train Loss: 2.7810 Acc: 0.3482
# Val Loss: 2.9408 Acc: 0.3170
#
# Training complete in 57m 45s
# Best Validation Accuracy: 0.3216, Epoch: 56

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes

#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005, nesterov = True)
optimizer_ft = torch.optim.Adam(model_ft.parameters(), lr=0.001, weight_decay=0.001)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.7)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)
#exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.0001, max_lr=0.001, step_size_up=3000)

#Train
model_ft = train_model('model_res_adam_1',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.431)
# 	validation       	 (min:    0.049, max:    0.494, cur:    0.382)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.347)
# 	validation       	 (min:    2.112, max:    4.888, cur:    2.623)
# Train Loss: 2.3471 Acc: 0.4313
# Val Loss: 2.6234 Acc: 0.3820
#
# Training complete in 57m 45s
# Best Validation Accuracy: 0.38370000000000004, Epoch: 53

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes

model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = torch.optim.Adam(model_ft.parameters(), lr=0.001, weight_decay=0.001)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 35], gamma=0.1)

#exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.01, max_lr=0.1)
#Train
model_ft = train_model('model_dense_adam',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 70, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.412)
# 	validation       	 (min:    0.049, max:    0.494, cur:    0.373)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.483)
# 	validation       	 (min:    2.112, max:    4.888, cur:    2.668)
# Train Loss: 2.4832 Acc: 0.4123
# Val Loss: 2.6676 Acc: 0.3729
#
# Epoch 70/70
# ----------
# Iteration: 161/1000, Loss: 225.6230354309082..
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes

#Load Resnet18
model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, nesterov = True, weight_decay = 0.003)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 35, 40], gamma=0.1)

#Train
model_ft = train_model('model_dense_2',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 65, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.456)
# 	validation       	 (min:    0.049, max:    0.494, cur:    0.416)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.317)
# 	validation       	 (min:    2.112, max:    5.038, cur:    2.475)
# Train Loss: 2.3169 Acc: 0.4558
# Val Loss: 2.4746 Acc: 0.4164
#
# Epoch 64/65
# ----------
# Iteration: 79/100, Loss: 205.26020526885986.4.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs=5, scheduler=None):
    if not os.path.exists('models/'+str(output_path)):
        os.makedirs('models/'+str(output_path))
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    since = time.time()
    liveloss = PlotLosses()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best = 0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i,(inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        scheduler.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                print("\rIteration: {}/{}, Loss: {}.".format(i+1, len(dataloaders[phase]), loss.item() * inputs.size(0)), end="")

#                 print( (i+1)*100. / len(dataloaders[phase]), "% Complete" )
                sys.stdout.flush()
                
            #if scheduler != None:
            #    scheduler.step()  
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            if phase == 'train':
                avg_loss = epoch_loss
                t_acc = epoch_acc
            else:
                val_loss = epoch_loss
                val_acc = epoch_acc
            
#             print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                 phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best = epoch + 1
                best_model_wts = copy.deepcopy(model.state_dict())
                
        liveloss.update({
            'log loss': avg_loss,
            'val_log loss': val_loss,
            'accuracy': t_acc,
            'val_accuracy': val_acc
        })
                
        liveloss.draw()
        print('Train Loss: {:.4f} Acc: {:.4f}'.format(avg_loss, t_acc))
        print(  'Val Loss: {:.4f} Acc: {:.4f}'.format(val_loss, val_acc))
        print()
        if epoch % 5 == 0:
            torch.save(model.state_dict(), './models/' + str(output_path) + '/model_{}_epoch.pt'.format(epoch+1))
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best Validation Accuracy: {}, Epoch: {}'.format(best_acc, best))

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes

model_ft = models.densenet121()
#Finetune Final few layers to adjust for tiny imagenet input
#model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.classifier.in_features
model_ft.classifier = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.07, momentum=0.9, nesterov = True, weight_decay = 0.001)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 35], gamma=0.1)

exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.01, max_lr=0.1)
#Train
model_ft = train_model('model_dense_cycl',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.337)
# 	validation       	 (min:    0.049, max:    0.494, cur:    0.250)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.834)
# 	validation       	 (min:    2.112, max:    5.038, cur:    3.410)
# Train Loss: 2.8345 Acc: 0.3372
# Val Loss: 3.4096 Acc: 0.2499
#
# Epoch 39/60
# ----------
# Iteration: 74/1000, Loss: 284.23426151275635.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-7fb658d66195> in <module>
#      45 exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.01, max_lr=0.1)
#      46 #Train
# ---> 47 model_ft = train_model('model_dense_cycl',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
#
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.001, nesterov = True)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)
exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.001, max_lr=0.05, step_size_up=3000)

#Train
model_ft = train_model('model_res_cycl',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.343)
# 	validation       	 (min:    0.049, max:    0.494, cur:    0.277)
# log loss
# 	training         	 (min:    1.451, max:    4.832, cur:    2.793)
# 	validation       	 (min:    2.112, max:    5.038, cur:    3.188)
# Train Loss: 2.7931 Acc: 0.3435
# Val Loss: 3.1882 Acc: 0.2770
#
# Epoch 35/60
# ----------
# Iteration: 1/1000, Loss: 276.3377904891968.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-935b2d472042> in <module>
#      47
#      48 #Train
# ---> 49 model_ft = train_model('model_res_cycl',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
#
# <ipython-input-32-a1148cfbb065> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      23
#      24             # Iterate over data.
# ...

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.001, nesterov = True)

# Decay LR by a factor of 0.1 every 7 epochs
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)
exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.003, max_lr=0.03,step_size_up=20000, mode = 'triangular')

#Train
model_ft = train_model('model_res_cycl_2',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.042, max:    0.632, cur:    0.469)
# 	validation       	 (min:    0.048, max:    0.494, cur:    0.385)
# log loss
# 	training         	 (min:    1.451, max:    4.849, cur:    2.142)
# 	validation       	 (min:    2.112, max:    5.038, cur:    2.659)
# Train Loss: 2.1417 Acc: 0.4691
# Val Loss: 2.6594 Acc: 0.3848
#
# Epoch 48/60
# ----------
# Iteration: 301/1000, Loss: 198.17694425582886.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-b521ef81e411> in <module>
#      47
#      48 #Train
# ---> 49 model_ft = train_model('model_res_cycl_2',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)
#
# <ipython-input-32-a1148cfbb065> in train_model(output_path, model, dataloaders, dataset_sizes, criterion, optimizer, num_epochs, scheduler)
#      44
#      45                 # statistics
# ...

# %%
#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005, nesterov = True)
optimizer_ft = torch.optim.Adam(model_ft.parameters(), lr=0.001, weight_decay=0.001)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.1)
#exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[25, 39], gamma=0.1)
#exp_lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer_ft, base_lr=0.0001, max_lr=0.001, step_size_up=3000)

#Train
model_ft = train_model('model_resn_adam',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        #transforms.CenterCrop(50),
        #transforms.Resize((64,64), interpolation=2),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.002, nesterov = True)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[22, 37], gamma=0.1)

#Train
model_ft = train_model('model_rot_mult',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 60, exp_lr_scheduler)

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(64, 64), scale = (0.6, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ToTensor(),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
    ]),
}

data_dir = 'tiny-imagenet-200'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True, num_workers=64)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
# class_names = image_datasets['train'].classes


#Load Resnet18
model_ft = models.resnet18()
#Finetune Final few layers to adjust for tiny imagenet input
model_ft.avgpool = nn.AdaptiveAvgPool2d(1)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 200)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
#Multi GPU
#model_ft = torch.nn.DataParallel(model_ft, device_ids=[0, 1])

#Loss Function
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.05, momentum=0.9, weight_decay=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[7, 20], gamma=0.1)
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)


#Train
model_ft = train_model('model_3',model_ft, dataloaders, dataset_sizes, criterion, optimizer_ft, 35, exp_lr_scheduler)
# Out:
# accuracy
# 	training         	 (min:    0.007, max:    0.518, cur:    0.430)
# 	validation       	 (min:    0.007, max:    0.412, cur:    0.354)
# log loss
# 	training         	 (min:    1.944, max:    5.509, cur:    2.362)
# 	validation       	 (min:    2.464, max:    5.507, cur:    2.794)
# Train Loss: 2.3616 Acc: 0.4302
# Val Loss: 2.7941 Acc: 0.3537
#
# Training complete in 30m 52s
# Best Validation Accuracy: 0.3623, Epoch: 29
